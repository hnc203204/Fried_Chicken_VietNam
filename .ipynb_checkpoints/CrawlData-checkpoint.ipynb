# %% [markdown]
# <h1>Facebook Data Crawling</h1>
# <p>In this notebook, we will crawling data from Facebook using the Facebook Graph API</p>

# %% [markdown]
# <h3>Install necessary library</h3>

# %%
# %pip install facebook-scraper pandas numpy
# Out:
# Requirement already satisfied: facebook-scraper in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (0.2.59)
# Requirement already satisfied: pandas in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: numpy in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (1.1.8)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.5 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (3.0.6)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2022.7.9)
# Requirement already satisfied: tzlocal in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (5.2)
# Requirement already satisfied: six>=1.5 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: requests in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.31.0)
# Requirement already satisfied: pyquery in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.0)
# Requirement already satisfied: fake-useragent in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.3.0)
# Requirement already satisfied: parse in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.19.1)
# Requirement already satisfied: bs4 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (0.0.1)
# Requirement already satisfied: w3lib in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.21.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (6.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (10.4)
# Requirement already satisfied: beautifulsoup4 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.4)
# Requirement already satisfied: zipp>=0.5 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.11.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from facebook_scraper import *
import time
import datetime

# %% [markdown]
# <h3>Crawling process</h3>

# %%
FANPAGE_LINKS = ["JollibeeVietnam", "ilovelotteria", "PopeyesVN", "KFCVietnam"]
FOLDER_PATH = "./Data2"
COOKIE_PATH = "./cookies.txt"
OPTION = {"comments": True, "reactions": True, "allow_extra_requests": True, "posts_per_page":10}

PAGES_NUMBER = 40

post_link = {
    fanpage : [] for fanpage in FANPAGE_LINKS
}

# %% [markdown]
# <h3>Crawling Jollibee VietNam</h3>

# %%
import random

def handle_pagination_url(url):
        global start_url
        start_url = url

FANPAGE_LINK = FANPAGE_LINKS[0]

    

while True:
    try:
        for post in get_posts(FANPAGE_LINK,
                    options = {  "comments" : True,"reactions": True, "allow_extra_requests": True ,
                               "post_per_page" : 100,"reactors" :False},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH,page_limit=None, start_url=start_url, request_url_callback=handle_pagination_url ) :
            post["start_url"] = start_url

            post_link[FANPAGE_LINK].append(post)
            print(len(post_link[FANPAGE_LINK]))
            time.sleep(random.randrange(2, 10, 1));
        print("All done")
        break;

    except exceptions.TemporarilyBanned:
        print("Temporarily banned, sleeping for 10m")
        time.sleep(1000)
# Out:
# 155
# /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:908: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/ufi/reaction/profile/browser/fetch/?ft_ent_identifier=pfbid0i1XjBG4wL8jsQLcTQBwv5DsQTixGmYfWzsGpiHCNiNtfTKmVHdomE9yjA4WTNckWl&limit=50&shown_ids=100004264331694%2C100004220627817%2C100004192652630%2C100004071879982%2C100004029889254%2C100004022439563%2C100003821410974%2C100003799581860%2C100003725212716%2C100003553307579%2C100003241556080%2C100003221191439%2C100003087993621%2C100003003259535%2C100002840078426%2C100002812204623%2C100002650377672%2C100002507493511%2C100001716400236%2C100001667052082%2C100001609894387%2C100001535155746%2C100001481160712%2C100001441490225%2C100000868793347%2C100
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#      11 while True:
#      12     try:
# ---> 13         for post in get_posts(FANPAGE_LINK,
#      14                     options = {  "comments" : True,"reactions": True, "allow_extra_requests": True ,
#      15                                "post_per_page" : 100,"reactors" :False},
#      16                     extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH,page_limit=None, start_url=start_url, request_url_callback=handle_pagination_url ) :
#      17             post["start_url"] = start_url
#      19             post_link[FANPAGE_LINK].append(post)
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:1117, in FacebookScraper._generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
#    1115 logger.debug("Extracting posts from page %s", i)
#    1116 for post_element in page:
# -> 1117     post = extract_post_fn(post_element, options=options, request_fn=self.get)
#    1118     if remove_source:
#    1119         post.pop('source', None)
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:33, in extract_post(raw_post, options, request_fn, full_post_html)
#      30 def extract_post(
#      31     raw_post: RawPost, options: Options, request_fn: RequestFunction, full_post_html=None
#      32 ) -> Post:
# ---> 33     return PostExtractor(raw_post, options, request_fn, full_post_html).extract_post()
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:236, in PostExtractor.extract_post(self)
#     233 post["comments_full"] = self.extract_comments_full()
#     234 if self.options.get("comments") != "generator":
#     235     # Consume both comment generator and reply generator to return lists
# --> 236     post["comments_full"] = utils.safe_consume(post["comments_full"])
#     237     for comment in post["comments_full"]:
#     238         comment["replies"] = utils.safe_consume(comment["replies"])
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py:279, in safe_consume(generator, sleep)
#     277 result = []
#     278 try:
# --> 279     for item in generator:
#     280         result.append(item)
#     281         time.sleep(sleep)
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:1210, in PostExtractor.extract_comments_full(self)
#    1207     return
#    1209 for comment in comments:
# -> 1210     result = self.extract_comment_with_replies(comment)
#    1211     if result:
#    1212         yield result
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:1169, in PostExtractor.extract_comment_with_replies(self, comment)
#    1167 def extract_comment_with_replies(self, comment):
#    1168     try:
# -> 1169         result = self.parse_comment(comment)
#    1170         result["replies"] = [
#    1171             self.parse_comment(reply)
#    1172             for reply in comment.find("div[data-sigil='comment inline-reply']")
#    1173         ]
#    1174         replies_url = comment.find(
#    1175             "div.async_elem[data-sigil='replies-see-more'] a[href],div[id*='comment_replies_more'] a[href]",
#    1176             first=True,
#    1177         )
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:1086, in PostExtractor.parse_comment(self, comment)
#    1080 reactors = comment.find(
#    1081     'a[href^="/ufi/reaction/profile/browser/?ft_ent_identifier="] i,'
#    1082     'a[href^="/ufi/reaction/profile/browser/?ft_ent_identifier="] img',
#    1083     first=True,
#    1084 )
#    1085 if reactors:
# -> 1086     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#    1087     if comment_reactors_opt != "generator":
#    1088         reactions["reactors"] = utils.safe_consume(reactions.get("reactors", []))
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py:817, in PostExtractor.extract_reactions(self, post_id, force_parse_HTML)
#     815 reaction_url = f'https://m.facebook.com/ufi/reaction/profile/browser/?ft_ent_identifier={post_id}'
#     816 logger.debug(f"Fetching {reaction_url}")
# --> 817 response = self.request(reaction_url)
#     818 if not reactions or force_parse_HTML:
#     819     reactions = {}
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:871, in FacebookScraper.get(self, url, **kwargs)
#     869     response = self.session.post(url=url, **kwargs)
#     870 else:
# --> 871     response = self.session.get(url=url, **self.requests_kwargs, **kwargs)
#     872 DEBUG = False
#     873 if DEBUG:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:831, in HTTPResponse.read_chunked(self, amt, decode_content)
#     829 if self.chunk_left == 0:
#     830     break
# --> 831 chunk = self._handle_chunk(amt)
#     832 decoded = self._decode(
#     833     chunk, decode_content=decode_content, flush_decoder=False
#     834 )
#     835 if decoded:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:784, in HTTPResponse._handle_chunk(self, amt)
#     782     returned_chunk = value
#     783 else:  # amt > self.chunk_left
# --> 784     returned_chunk = self._fp._safe_read(self.chunk_left)
#     785     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     786     self.chunk_left = None
#
# File ~/anaconda3/lib/python3.11/http/client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# <h3>Crawling Lotteria</h3>

# %%
import random

def handle_pagination_url(url):
        global start_url
        start_url = url

FANPAGE_LINK = FANPAGE_LINKS[1]

    

while True:
    try:
        for post in get_posts(FANPAGE_LINK,
                    options = {  "comments" : True,"reactions": True, "allow_extra_requests": True ,
                               "post_per_page" : 100,"reactors" :False},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH,page_limit=None, start_url=start_url, request_url_callback=handle_pagination_url ) :
            post["start_url"] = start_url

            post_link[FANPAGE_LINK].append(post)
            print(len(post_link[FANPAGE_LINK]))
            time.sleep(random.randrange(2, 10, 1));
        print("All done")
        break;

    except exceptions.TemporarilyBanned:
        print("Temporarily banned, sleeping for 10m")
        time.sleep(1000)

# %%
len(post_link[FANPAGE_LINK[1]])
# Out:
# 118

# %% [markdown]
# <h3>Crawling Popeyes</h3>

# %%
import random

def handle_pagination_url(url):
        global start_url
        start_url = url

FANPAGE_LINK = FANPAGE_LINKS[2]

    

while True:
    try:
        for post in get_posts(FANPAGE_LINK,
                    options = {  "comments" : True,"reactions": True, "allow_extra_requests": True ,
                               "post_per_page" : 100,"reactors" :False},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH,page_limit=None, start_url=start_url, request_url_callback=handle_pagination_url ) :
            post["start_url"] = start_url

            post_link[FANPAGE_LINK].append(post)
            print(len(post_link[FANPAGE_LINK]))
            time.sleep(random.randrange(2, 10, 1));
        print("All done")
        break;

    except exceptions.TemporarilyBanned:
        print("Temporarily banned, sleeping for 10m")
        time.sleep(1000)
# Out:
# /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# /Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:908: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/ufi/reaction/profile/browser/fetch/?ft_ent_identifier=pfbid02QddDTGKjaj35xm7pM1zrr5tc2W79kfQDSSHNiGGvTJhjfRu56hYrQcHiY3QJDteGl&limit=50&shown_ids=100007138033535%2C100007001981747%2C100006802444582%2C100006676541989%2C100006669063822%2C100006520141238%2C100006403650857%2C100005899742890%2C100005780352524%2C100005536518206%2C100005455500781%2C100005451011525%2C100005190797976%2C100004688792868%2C100004564992331%2C100004561574193%2C100004463313380%2C100004340442952%2C100004185969890%2C100004184172079%2C100003975739468%2C100003943620729%2C100003892183848%2C100003883645048%2C100003215957382%2C100002682811042%2C100002238898015%2C100001590753368%2C100001426033395%2C100000653500667%2C100000299782609%2C100000188545908%2C100000145216534%2C100000001251827%2C61553552561043%2C1823192961%2C1797262651%2C100092848091975%2C100092438070330%2C100087913943405%2C100083739769592%2C100078906188432%2C100075618739047%2C100074830151595%2C100072966456473%2C100067900593320%2C100058710039682%2C100057680541614%2C100053560764193%2C100053293691518%2C100051334670265%2C100050218981589%2C100040116221266%2C100039584582584%2C100039027847073%2C100038003653089%2C100034853349300%2C100034816672519%2C100034755677908%2C100034397297307%2C100030068479107%2C100029599008202%2C100026274467
811%2C100011878590833%2C100011826250450%2C100011780319777%2C100011755270961%2C100011709257952%2C100011590981970%2C100011501311693%2C100011439190094%2C100011350630575%2C100011301973841%2C100011276170528%2C100011183589325%2C100011056410423%2C100010986692694%2C100010899429977%2C100010678962618%2C100010221403138%2C100010037642324%2C100009890080649%2C100009848432864%2C100009708791892%2C100009618793850%2C100009512061288%2C100009494675757%2C100009458564537%2C100009411106835%2C100009317853220%2C100009244569553%2C100009184538083%2C100009078283159%2C100008967754763%2C100008566248090%2C100008415016899%2C100008339440761%2C100008333927566%2C100008261535359%2C100008226812040%2C100008206126792%2C100008188752975%2C100008187161834%2C100008080448919%2C100008049196522%2C100007995465628%2C100007842738999%2C100007822634653%2C100007797884732%2C100028525572089%2C100028215397004%2C100027751372242%2C100027288942548%2C100026941158243%2C100026698215146%2C100026274467206%2C100025838119788%2C100025266540612%2C100025265360502%2C100025160795647%2C100025143622428%2C100025005732532%2C100024806402496%2C100023845757616%2C100023833115736%2C100022287733301%2C100022247023374%2C100022197879543%2C100017662302902%2C100017606820745%2C100017479022971%2C100017309431945%2C100016854016349%2C100016730380543%2C100016686164515%2C100016150961598%2C100015620734821%2C100015347431621%2C100015281977768%2C100015137739747%2C100015137444191%2C100015068168936%2C100014852343055%2C100014588981077%2C100014566458739%2C100014563503788%2C100014382737776%2C100014125004835%2C100013805182262%2C100013598598855%2C100013256626505%2C100013060628404%2C100012678790592%2C100012577542229%2C100012379635831%2C100012164141775%2C100012053436106%2C100054959560210%2C100054712817689%2C100054535389431%2C10 ...
#   warnings.warn(
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1161, in extract_comment_replies
#     yield self.parse_comment(reply)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Traceback (most recent call last):
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1210, in extract_comments_full
#     result = self.extract_comment_with_replies(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1169, in extract_comment_with_replies
#     result = self.parse_comment(comment)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 1086, in parse_comment
#     reactions = self.extract_reactions(comment_id, force_parse_HTML=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/extractors.py", line 817, in extract_reactions
#     response = self.request(reaction_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nguyenhuynh/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py", line 929, in get
#     raise exceptions.TemporarilyBanned(title.text)
# facebook_scraper.exceptions.TemporarilyBanned: You’re Temporarily Blocked
# Sleep 10 minutes
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.11/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.11/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[25], line 3
#       1 while True:
#       2     try:
# ----> 3         for post in get_posts(FANPAGE_LINK[2],
#       4                             options=OPTION,
#       5                             extra_info = True,
#       6                             pages = PAGES_NUMBER, cookies=COOKIE_PATH):
#       7             post_link[FANPAGE_LINK[2]].append(post)
#       8         print("All done")
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:1114, in FacebookScraper._generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
#    1111 counter = itertools.count(0) if page_limit is None else range(page_limit)
#    1113 logger.debug("Starting to iterate pages")
# -> 1114 for i, page in zip(counter, iter_pages_fn()):
#    1115     logger.debug("Extracting posts from page %s", i)
#    1116     for post_element in page:
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/page_iterators.py:87, in generic_iter_pages(start_url, page_parser_cls, request_fn, **kwargs)
#      85 try:
#      86     logger.debug("Requesting page from: %s", next_url)
# ---> 87     response = request_fn(next_url)
#      88     break
#      89 except HTTPError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:871, in FacebookScraper.get(self, url, **kwargs)
#     869     response = self.session.post(url=url, **kwargs)
#     870 else:
# --> 871     response = self.session.get(url=url, **self.requests_kwargs, **kwargs)
#     872 DEBUG = False
#     873 if DEBUG:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
len(post_link[FANPAGE_LINK[2]])
# Out:
# 133

# %% [markdown]
# <h3>Crawling KFC</h3>

# %%
post_link[FANPAGE_LINK[3]] = []

# %%
import random

def handle_pagination_url(url):
        global start_url
        start_url = url

FANPAGE_LINK = FANPAGE_LINKS[3]

    

while True:
    try:
        for post in get_posts(FANPAGE_LINK,
                    options = {  "comments" : True,"reactions": True, "allow_extra_requests": True ,
                               "post_per_page" : 100,"reactors" :False},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH,page_limit=None, start_url=start_url, request_url_callback=handle_pagination_url ) :
            post["start_url"] = start_url

            post_link[FANPAGE_LINK].append(post)
            print(len(post_link[FANPAGE_LINK]))
            time.sleep(random.randrange(2, 10, 1));
        print("All done")
        break;

    except exceptions.TemporarilyBanned:
        print("Temporarily banned, sleeping for 10m")
        time.sleep(1000)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.11/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.11/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[77], line 3
#       1 while True:
#       2     try:
# ----> 3         for post in get_posts(FANPAGE_LINK[3],
#       4                             options=OPTION,
#       5                               timeout=100,
#       6                             extra_info = True,
#       7                             pages = PAGES_NUMBER, cookies=COOKIE_PATH):
#       8             post_link[FANPAGE_LINK[3]].append(post)
#       9         print("All done")
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/__init__.py:196, in get_posts(account, group, post_urls, hashtag, credentials, **kwargs)
#     194 if cookies is not None and credentials is not None:
#     195     raise ValueError("Can't use cookies and credentials arguments at the same time")
# --> 196 set_cookies(cookies)
#     198 options: Union[Dict[str, Any], Set[str]] = kwargs.setdefault('options', {})
#     199 if isinstance(options, set):
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/__init__.py:51, in set_cookies(cookies)
#      49     raise exceptions.InvalidCookies(f"Missing cookies with name(s): {missing_cookies}")
#      50 _scraper.session.cookies.update(cookies)
# ---> 51 if not _scraper.is_logged_in():
#      52     raise exceptions.InvalidCookies(f"Cookies are not valid")
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:1003, in FacebookScraper.is_logged_in(self)
#    1001 def is_logged_in(self) -> bool:
#    1002     try:
# -> 1003         self.get('https://facebook.com/settings')
#    1004         return True
#    1005     except exceptions.LoginRequired:
#
# File ~/anaconda3/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:871, in FacebookScraper.get(self, url, **kwargs)
#     869     response = self.session.post(url=url, **kwargs)
#     870 else:
# --> 871     response = self.session.get(url=url, **self.requests_kwargs, **kwargs)
#     872 DEBUG = False
#     873 if DEBUG:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:725, in <listcomp>(.0)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
len(post_link[FANPAGE_LINK[3]])
# Out:
# 188

# %%
for fanpage in FANPAGE_LINK:
    try:
        post_df_full = pd.DataFrame(post_link[fanpage], columns=post_link[fanpage][0].keys(), index=range(len(post_link[fanpage])))
        post_df_full["time"] = pd.to_datetime(post_df_full["time"])
        post_df_full = post_df_full[post_df_full['time'] > pd.to_datetime('2022-12-01')]
        path = FOLDER_PATH + "/" + fanpage + ".csv"
        post_df_full.to_csv(path)
    except:
        continue
    print(path)
# Out:
# ./Data/JollibeeVietnam.csv
# ./Data/ilovelotteria.csv
# ./Data/PopeyesVN.csv
# ./Data/KFCVietnam.csv
